# %%
import numpy as np
import pandas as pd 
import scipy.stats as stats
import itertools

# %%
df = pd.read_csv('data/2/adult.data', header=None).drop(columns=14)
df
# Out:
#        0                  1       2            3   4                    5   \
# 0      39          State-gov   77516    Bachelors  13        Never-married
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
df.columns = [
    'age',
    'workclass',
    'fnlwgt',
    'education',
    'education_num',
    'marital_status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'capital_gain',
    'capital_loss',
    'hours_per_week',
    'native_country'
]

# %%
df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital_gain        119
# capital_loss         92
# hours_per_week       94
# native_country       42
# dtype: int64

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country
# 0          2174             0              40   United-States
# ...

# %%
df.astype('category')
# Out:
#       age          workclass  fnlwgt    education education_num  \
# 0      39          State-gov   77516    Bachelors            13
# 1      50   Self-emp-not-inc   83311    Bachelors            13
# 2      38            Private  215646      HS-grad             9
# 3      53            Private  234721         11th             7
# 4      28            Private  338409    Bachelors            13
# ...    ..                ...     ...          ...           ...
# 32556  27            Private  257302   Assoc-acdm            12
# 32557  40            Private  154374      HS-grad             9
# 32558  58            Private  151910      HS-grad             9
# 32559  22            Private  201490      HS-grad             9
# 32560  52       Self-emp-inc  287927      HS-grad             9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.nunique()
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education_num        16
# marital_status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital_gain        119
# capital_loss         92
# hours_per_week       94
# native_country       42
# dtype: int64

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
def contingency_table_analysis(cat1, cat2):
    if not isinstance(df[cat1].dtype, pd.CategoricalDtype):
        df[cat1] = df[cat1].astype('category')
    if not isinstance(df[cat2].dtype, pd.CategoricalDtype):
        df[cat2] = df[cat2].astype('category')

    contingency_table = df.pivot_table(
        values='age',
        columns=cat2,
        index=cat1,
        aggfunc='count',
        margins=True,
        margins_name='Total'
    )

    m1, m2 = contingency_table.shape
    m1 -= 1
    m2 -= 1
    q = (m1-1)*(m2-1)
    
    expected_frequency_table = contingency_table.apply(
        lambda x : x[-1] * contingency_table.iloc[:, -1] / contingency_table.iloc[-1, -1]
    )

    chi2_value = ((expected_frequency_table - contingency_table)**2 / expected_frequency_table).sum().sum()

    chi2_stats = stats.chi2(q)

    p_value = 1 - chi2_stats.cdf(chi2_value)

    return chi2_value, p_value

# %%
contingency_table_analysis('education', 'race')
# Out:
# C:\Users\caohu\AppData\Local\Temp\ipykernel_24648\1011353905.py:7: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   contingency_table = df.pivot_table(
# C:\Users\caohu\AppData\Local\Temp\ipykernel_24648\1011353905.py:22: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda x : x[-1] * contingency_table.iloc[:, -1] / contingency_table.iloc[-1, -1]
# ...

# %% [markdown]
# validate

# %%
contingency_table = df.pivot_table(
    index='education',
    columns='race',
    aggfunc='count',
    values='age'
)
contingency_table
# Out:
# C:\Users\caohu\AppData\Local\Temp\ipykernel_24648\1698713350.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   contingency_table = df.pivot_table(
# race          Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White
# education
# 10th                          16                  13    133      9    762
# 11th                          14                  21    153     10    977
# 12th                           5                   9     70     14    335
# 1st-4th                        4                   5     16      9    134
# 5th-6th                        2                  18     21     13    279
# 7th-8th                        9                  11     56     17    553
# 9th                            5                   9     89      8    403
# ...

# %%
stat, p_value, dof, expected = stats.chi2_contingency(contingency_table)

# %%
stat
# Out:
# 730.6712962254584

# %%
p
# Out:
# 5.547319569858434e-116

# %%
alpha = 1 - 0.99
alpha
# Out:
# 0.010000000000000009

# %% [markdown]
# degree of freedom

# %%
m1, m2 = contingency_table.shape
q = (m1-1)*(m2-1)

# %% [markdown]
# test ppf (percent point function)

# %% [markdown]
# if chi_square statistic > critical value -> co moi lien he giua hai bien </br>
# if chi_square_statistic <= critical value -> khong du bang chung ket luan

# %%
v_a = stats.chi2.ppf(1- alpha, 6)
v_a
# Out:
# 16.811893829770927

# %%
q, dof
# Out:
# (60, 60)

# %%
v_a = stats.chi2.ppf(1-alpha, q)
v_a
# Out:
# 88.37941890144937

# %%
p_value
# Out:
# 5.547319569858434e-116

# %% [markdown]
# Because p_value is smaller than v_a, we can conculde that they are independent
